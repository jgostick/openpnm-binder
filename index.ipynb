# %% [markdown]
# # Introduction to OpenPNM

# %% [markdown]
# To get started using PoreSpy, import all the packages that will be needed:

# %%
import openpnm as op

# %% [markdown]
# Start by generating a simple cubic network

# %%
pn = op.network.Cubic([4, 5, 6])
op.visualization.plot_connections(pn)
